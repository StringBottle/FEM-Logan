# %% [markdown]
# 2.1
#     a. Obtain the gloal stiffness matrix $[K]$ of the assembalge shown in Figure P2-1 by superimposing the stiffness matrices of the individual springs. Here k1, k2, and k3 are the stiffnesses of the springs as shown

# %% [markdown]
# $$
# K_{1} = \begin{bmatrix}
# k_{1} & -k_{1} \\
# -k_{1} & k_{1}
# \end{bmatrix}
# $$
#
# $$
# K_{2} = \begin{bmatrix}
# k_{2} & -k_{2} \\
# -k_{2} & k_{2}
# \end{bmatrix}
# $$
#
# $$
# K_{3} = \begin{bmatrix}
# k_{3} & -k_{3} \\
# -k_{3} & k_{3}
# \end{bmatrix}
# $$

# %% [markdown]
# $$
# K = K_{1} + K_{2} + K_{3}
# $$
#
# $$
# K = \begin{bmatrix}
# k_{1} & 0 & -k_{1} & 0 \\
# 0 & k_{3} & 0  & -k_{3} \\
# -k_{1} & 0 &  k_{1} + k_{2}  & -k_{2} \\
# 0 & -k_{3} &  -k_{2} &  k_{2} + k_{3}
# \end{bmatrix}
# $$

# %% [markdown]
# b. If nodes 1 and 2 are fixed and a force P acts on node 4 in the positive x direction, find an expression for the displacements of nodes 3 and 4.

# %% [markdown]
# $$
# F = KU
# $$
#
# $$
# \begin{bmatrix}
# F_{1} \\
# F_{2} \\
# F_{3} \\
# P \\
# \end{bmatrix}
# = \begin{bmatrix}
# k_{1} & 0 & -k_{1} & 0 \\
# 0 & k_{3} & 0  & -k_{3} \\
# -k_{1} & 0 &  k_{1} + k_{2}  & -k_{2} \\
# 0 & -k_{3} &  -k_{2} &  k_{2} + k_{3}
# \end{bmatrix}
#  \begin{bmatrix}
# u_{1} \\
# u_{2} \\
# u_{3} \\
# u_{4} \\
# \end{bmatrix}
# $$
#
# $$
# \begin{bmatrix}
# F_{3} \\
# P \\
# \end{bmatrix}
# = \begin{bmatrix}
#   k_{1} + k_{2}  & -k_{2} \\
#   -k_{2} &  k_{2} + k_{3}
# \end{bmatrix}
#  \begin{bmatrix}
# u_{3} \\
# u_{4} \\
# \end{bmatrix}
# $$
#
# $$
# \begin{bmatrix}
# 0 \\
# P \\
# \end{bmatrix}
# = \begin{bmatrix}
#   k_{1} + k_{2}  & -k_{2} \\
#   -k_{2} &  k_{2} + k_{3}
# \end{bmatrix}
#  \begin{bmatrix}
# u_{3} \\
# u_{4} \\
# \end{bmatrix}
# $$
#
# $$
# 0 = (k_{1}+k_{2})u_{3}-k_{2}u_{4}
# $$
#
# $$
# P = -k_{2}u_{3}+(k_{2}+k_{3})u_{4}
# $$
#
# $$
# 0 = k_{2}u_{3}-\frac{{k_{2}}^2}{(k_{1}+k_{2})}u_{4}
# $$
#
# $$
# P = -k_{2}u_{3}+(k_{2}+k_{3})u_{4}
# $$
#
#
# $$
# P = -\frac{{k_{2}}^2}{(k_{1}+k_{2})}u_{4}+(k_{2}+k_{3})u_{4}
# $$
#
# $$
# P = \frac{k_{1}k_{2}+k_{2}k_{3}+k_{1}k_{3}}{(k_{1}+k_{2})}u_{4}
# $$
#
# $$
# u_{4} = \frac{P(k_{1}+k_{2})}{k_{1}k_{2}+k_{2}k_{3}+k_{1}k_{3}}
# $$
#
# $$
# u_{3} = \frac{k_{2}P}{k_{1}k_{2}+k_{2}k_{3}+k_{1}k_{3}}
# $$

# %% [markdown]
# c. Determine the reaction forces at nodes 1 and 2.

# %% [markdown]
# $$
# \begin{bmatrix}
# F_{1} \\
# F_{2} \\
# F_{3} \\
# P \\
# \end{bmatrix}
# = \begin{bmatrix}
# k_{1} & 0 & -k_{1} & 0 \\
# 0 & k_{3} & 0  & -k_{3} \\
# -k_{1} & 0 &  k_{1} + k_{2}  & -k_{2} \\
# 0 & -k_{3} &  -k_{2} &  k_{2} + k_{3}
# \end{bmatrix}
#  \begin{bmatrix}
# u_{1} \\
# u_{2} \\
# u_{3} \\
# u_{4} \\
# \end{bmatrix}
# $$
#
# $$
# F_{1} = k_{1}u_{1} - k_{1}u_{3}
# $$
# $$
# F_{2} = k_{3}u_{2} - k_{3}u_{4}
# $$
#
# Consider $u_{1}$ and $u_{2}$ are zero, we get
#
# $$
# F_{1} = - k_{1}u_{3}
# $$
# $$
# F_{2} = - k_{3}u_{4}
# $$
#
# Substitute $u_{3}$ and $u_{4}$ with the value obtained in 2.1.b.
# $$
# F_{1} = \frac{-k_{1}k_{2}P}{k_{1}k_{2}+k_{2}k_{3}+k_{1}k_{3}}
# $$
#
# $$
# F_{2} = \frac{-k_{3}P(k_{1}+k_{2})}{k_{1}k_{2}+k_{2}k_{3}+k_{1}k_{3}}
# $$
